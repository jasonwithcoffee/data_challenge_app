# %% [markdown]
# # App Store Data Challenge

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# !ls ../challenge_data/
# Out:
# Data challenge instructions - AR.pdf device_ref.csv
# account_dat.csv                      in-app_dat.csv
# app_dat.csv                          transaction_dat.csv
# category_ref.csv

# %%
df_account = pd.read_csv('../challenge_data/account_dat.csv')
df_app = pd.read_csv('../challenge_data/app_dat.csv')
df_category = pd.read_csv('../challenge_data/category_ref.csv')
df_device = pd.read_csv('../challenge_data/device_ref.csv')
df_in_app = pd.read_csv('../challenge_data/in-app_dat.csv')
df_transaction = pd.read_csv('../challenge_data/transaction_dat.csv')

# %%
df_account.head()
# Out:
#             acct_id create_dt payment_type
# 0  eb23e449d274bddb    4/3/12         PMOF
# 1  3d60dcb8494a0d70   8/31/09         PMOF
# 2  9b6d6fbf76504d85   11/6/08         PMOF
# 3  343255370828b380    1/3/12         PMOF
# 4  664e27f05189c387  10/31/10         PMOF

# %%
df_app.head()
# Out:
#                app_name        content_id category_id  device_id
# 0  half-slouched having  22dfac9721b899cb         Y-8          3
# 1      lift whale-ships  7c645810cd7f166e         M-7          3
# 2    mightily community  c495bcb878faffaa         Y-8          2
# 3   session: too--shall  4e683dcd461cdd22         Y-8          1
# 4          That Zoology  6473dd29a2badbf1         Y-8          3

# %%
df_in_app.head()
# Out:
#   parent_app_content_id        content_id        type
# 0      d2bde35599e0dae9  227227a77c59809b  consumable
# 1      d2bde35599e0dae9  41ac2362a2600185  consumable
# 2      d2bde35599e0dae9  64a8e16f030bb611  consumable
# 3      d2bde35599e0dae9  2c8ba424183afa7c  consumable
# 4      d2bde35599e0dae9  b4c42fa5cc420f7b  consumable

# %%
df_category.head()
# Out:
#        category_name category_id
# 0              Games         Z-1
# 1  Social Networking         Q-5
# 2          Utilities         M-7
# 3      Entertainment         Q-1
# 4    Photos & Videos         Y-8

# %% [markdown]
# ### Denormalize data 3 dataframes
# 1. df_app_denorm: dataframe with info on category, content, and device
# 2. df_trn_denorm: dataframe with transactions, account, and device
# 3. df_wide: dataframe with all columns

# %%
# cast date columns as datetime objects
df_account['create_dt'] = pd.to_datetime(df_account['create_dt'])
df_transaction['create_dt'] = pd.to_datetime(df_transaction['create_dt'])

df_app_denorm = df_in_app.join(df_app.set_index('content_id'), on='parent_app_content_id')\
                .join(df_category.set_index('category_id'), on='category_id')\
                .join(df_device.set_index('device_id'), on='device_id')

df_trn_denorm = df_transaction.join(df_device.set_index('device_id'), on='device_id')\
                    .join(df_account.set_index('acct_id'), on='acct_id', lsuffix='_transaction', rsuffix='_acct')

df_wide = df_trn_denorm.join(df_app_denorm.drop(columns=['device_id','device_name'])\
                             .set_index('content_id'), on='content_id')

# %%
df_app_denorm.head()
# Out:
#   parent_app_content_id        content_id        type              app_name  \
# 0      d2bde35599e0dae9  227227a77c59809b  consumable  lactantem prevailing
# 1      d2bde35599e0dae9  41ac2362a2600185  consumable  lactantem prevailing
# 2      d2bde35599e0dae9  64a8e16f030bb611  consumable  lactantem prevailing
# 3      d2bde35599e0dae9  2c8ba424183afa7c  consumable  lactantem prevailing
# 4      d2bde35599e0dae9  b4c42fa5cc420f7b  consumable  lactantem prevailing
#
#   category_id  device_id category_name device_name
# 0         Z-1          3         Games        Both
# 1         Z-1          3         Games        Both
# 2         Z-1          3         Games        Both
# 3         Z-1          3         Games        Both
# 4         Z-1          3         Games        Both

# %%
df_trn_denorm.head()
# Out:
#   create_dt_transaction        content_id           acct_id  price  device_id  \
# 0            2016-08-28  b6cf4f33e7455df4  220574a7a6a71afa  11.99          1
# 1            2016-09-16  71ac3e9c38ddbbba  8551f69a5015ea6a   1.99          2
# 2            2016-08-15  776b851b916c33d1  7dedf309494a1966   0.99          2
# 3            2016-06-17  7a47ca132a8dc695  7174a81c796dcf7e   1.99          2
# 4            2016-06-13  30581219bc952dbb  35aaf59d64a677e7  11.99          2
#
#   device_name create_dt_acct payment_type
# 0      iPhone     2009-08-29         PMOF
# 1        iPad     2011-05-28         PMOF
# 2        iPad     2009-11-15         PMOF
# 3        iPad     2009-03-01         PMOF
# 4        iPad     2010-10-01         PMOF

# %%
df_wide.head()
# Out:
#   create_dt_transaction        content_id           acct_id  price  device_id  \
# 0            2016-08-28  b6cf4f33e7455df4  220574a7a6a71afa  11.99          1
# 1            2016-09-16  71ac3e9c38ddbbba  8551f69a5015ea6a   1.99          2
# 2            2016-08-15  776b851b916c33d1  7dedf309494a1966   0.99          2
# 3            2016-06-17  7a47ca132a8dc695  7174a81c796dcf7e   1.99          2
# 4            2016-06-13  30581219bc952dbb  35aaf59d64a677e7  11.99          2
#
#   device_name create_dt_acct payment_type parent_app_content_id          type  \
# 0      iPhone     2009-08-29         PMOF      61cea77b9bc843d1  subscription
# 1        iPad     2011-05-28         PMOF      1f0ebd67df5846cd    consumable
# 2        iPad     2009-11-15         PMOF      1383e4f2f49f0f44    consumable
# 3        iPad     2009-03-01         PMOF      8590a25d4e5c249c    consumable
# 4        iPad     2010-10-01         PMOF      478e10f9248b7842    consumable
#
#                    app_name category_id  category_name
# 0           events Bildad's         M-7      Utilities
# 1        swell questionably         M-7      Utilities
# 2  supperless--my Shipmates         Z-1          Games
# 3          unwritten hungry         Z-1          Games
# 4           Turning thanked         Q-1  Entertainment

# %%
df_wide.create_dt_acct
# Out:
# 0         2009-08-29
# 1         2011-05-28
# 2         2009-11-15
# 3         2009-03-01
# 4         2010-10-01
#              ...
# 3607504   2011-06-18
# 3607505   2010-01-25
# 3607506   2012-02-08
# 3607507   2007-08-29
# 3607508   2009-01-23
# Name: create_dt_acct, Length: 3607509, dtype: datetime64[ns]

# %%
df_wide[['content_id', 'payment_type']].groupby(by=['payment_type']).count()
# Out:
#               content_id
# payment_type
# Free only        1167271
# PMOF             2437496

# %%
# confirm that Free only has no price
df_wide[['price', 'payment_type']].groupby(by=['payment_type']).sum()
# Out:
#                     price
# payment_type
# Free only            0.00
# PMOF          19037307.25

# %%
df_wide[['content_id', 'payment_type', 'type']].groupby(by=['payment_type', 'type']).count()
# Out:
#                            content_id
# payment_type type
# PMOF         consumable       1820631
#              subscription      191210

# %%
df_wide[['price', 'payment_type', 'type']].groupby(by=['payment_type', 'type']).sum()
# Out:
#                                  price
# payment_type type
# PMOF         consumable    16797973.69
#              subscription   1214154.90

# %%
df_trn_denorm['price'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df_trn_denorm[['price', 'content_id']].groupby(by=['price']).count().sort_values(by='price')
# Out:
#        content_id
# price
# 0.00      1302194
# 0.99       332492
# 1.99       255790
# 2.99       204189
# 3.99       173033
# 4.99       131962
# 5.99       110628
# 6.99       110397
# 7.99        97863
# 8.99       107845
# 9.99        77249
# 10.99       73753
# 11.99       78908
# 12.99       52314
# 13.99       51855
# 14.99       54390
# 15.99       44749
# 16.99       42124
# 17.99       45096
# 18.99       36202
# 19.99       35044
# 20.99       28044
# 21.99       23722
# 22.99       21796
# 23.99       22256
# 24.99       23241
# 25.99       12305
# 26.99       18851
# 27.99       12899
# 28.99       18105
# 29.99        8213

# %%
df_wide.app_name.nunique()
# Out:
# 474

# %%
df_wide.create_dt_transaction.min()
# Out:
# Timestamp('2016-06-01 00:00:00')

# %%
df_wide.create_dt_transaction.max()
# Out:
# Timestamp('2016-09-21 00:00:00')

# %%
df_wide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3607509 entries, 0 to 3607508
# Data columns (total 13 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   create_dt_transaction  datetime64[ns]
#  1   content_id             object
#  2   acct_id                object
#  3   price                  float64
#  4   device_id              int64
#  5   device_name            object
#  6   create_dt_acct         datetime64[ns]
#  7   payment_type           object
#  8   parent_app_content_id  object
#  9   type                   object
#  10  app_name               object
#  11  category_id            object
#  12  category_name          object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(9)
# memory usage: 357.8+ MB

# %%
df_wide[['acct_id', 'payment_type', 'type']].groupby(by=['payment_type', 'type']).nunique()
# Out:
#                            acct_id
# payment_type type
# PMOF         consumable      14982
#              subscription    14982

# %%
df_wide[df_wide['type'] == 'subscription']['acct_id'].head()
# Out:
# 0     220574a7a6a71afa
# 10    7c004e23347f8cb4
# 42    8050627aaebd03ec
# 44    fd390bfb0290aa33
# 48    e488c4251e5ed684
# Name: acct_id, dtype: object

# %%
df_wide.acct_id.nunique()
# Out:
# 30000

# %%
df_wide[df_wide['acct_id'] == '8050627aaebd03ec']
# Out:
#         create_dt_transaction        content_id           acct_id  price  \
# 42                 2016-07-21  46a72469d6747411  8050627aaebd03ec   8.99
# 520                2016-06-22  02287dc66736c41d  8050627aaebd03ec   2.99
# 14865              2016-09-16  9464a17a955d8835  8050627aaebd03ec  19.99
# 38956              2016-08-02  42748b15beecf642  8050627aaebd03ec   1.99
# 54664              2016-07-20  b8938dadf2ae3e62  8050627aaebd03ec   3.99
# ...                       ...               ...               ...    ...
# 3561491            2016-08-04  7ba542812ee5767b  8050627aaebd03ec   4.99
# 3574099            2016-06-19  e3cab7eabde18cd2  8050627aaebd03ec  10.99
# 3579247            2016-08-03  f9029ad440d066d5  8050627aaebd03ec  15.99
# 3582994            2016-07-13  2ca245388845351d  8050627aaebd03ec  12.99
# 3589501            2016-09-01  256772b493761a01  8050627aaebd03ec   0.99
#
#          device_id device_name create_dt_acct payment_type  \
# 42               1      iPhone     2008-03-29         PMOF
# 520              1      iPhone     2008-03-29         PMOF
# 14865            1      iPhone     2008-03-29         PMOF
# 38956            1      iPhone     2008-03-29         PMOF
# 54664            1      iPhone     2008-03-29         PMOF
# ...            ...         ...            ...          ...
# 3561491          2        iPad     2008-03-29         PMOF
# 3574099          1      iPhone     2008-03-29         PMOF
# 3579247          1      iPhone     2008-03-29         PMOF
# 3582994          1      iPhone     2008-03-29         PMOF
# 3589501          1      iPhone     2008-03-29         PMOF
#
#         parent_app_content_id          type              app_name category_id  \
# 42           64a419e7440109f9  subscription           pry AMERICA         Q-1
# 520          1f0ebd67df5846cd    consumable    swell questionably         M-7
# 14865        4164b62f665e1181    consumable      one-half hearts'         Z-1
# 38956        80bdd67b6063c7ca    consumable  dim serpent-snapping         Y-8
# 54664        ac9b3b9697787ad8    consumable        animals levels         Z-1
# ...                       ...           ...                   ...         ...
# 3561491      08a1ebbb1e6e26cd    consumable   INDIRECT this--what         Z-1
# 3574099      9b553c5b5953f150    consumable      button sensitive         Z-1
# 3579247      85f1da2246f1f10a    consumable       taxes emigrants         Z-1
# 3582994      62bbc9735ee184a4    consumable           aright Davy         Z-1
# 3589501      d9ac236641bd3859    consumable     words: hospitable         Z-1
#
#            category_name
# 42         Entertainment
# 520            Utilities
# 14865              Games
# 38956    Photos & Videos
# 54664              Games
# ...                  ...
# 3561491            Games
# 3574099            Games
# 3579247            Games
# 3582994            Games
# 3589501            Games
#
# [143 rows x 13 columns]

# %%
df_wide[df_wide['type'] == 'subscription']['app_name'].unique().shape
# Out:
# (60,)

# %%
df_wide[df_wide['type'] == 'consumable']['app_name'].unique().shape
# Out:
# (414,)

# %% [markdown]
# ## Investigate payment_type

# %%
df_wide[df_wide['payment_type'] == 'PMOF']
# Out:
#         create_dt_transaction        content_id           acct_id  price  \
# 0                  2016-08-28  b6cf4f33e7455df4  220574a7a6a71afa  11.99
# 1                  2016-09-16  71ac3e9c38ddbbba  8551f69a5015ea6a   1.99
# 2                  2016-08-15  776b851b916c33d1  7dedf309494a1966   0.99
# 3                  2016-06-17  7a47ca132a8dc695  7174a81c796dcf7e   1.99
# 4                  2016-06-13  30581219bc952dbb  35aaf59d64a677e7  11.99
# ...                       ...               ...               ...    ...
# 3607504            2016-07-11  330640111f15f83e  42f1c3996d40fa49  27.99
# 3607505            2016-08-05  2364a51706a7f5a3  63f4e3bbaf70abbe   2.99
# 3607506            2016-06-28  26aebfbbaec60a96  402001eac02d9f8a   6.99
# 3607507            2016-06-09  77ee563bf7d7c534  514434e3ad0b8e64   2.99
# 3607508            2016-07-17  d0ae61e1a666bd74  b884477673ef801d  11.99
#
#          device_id device_name create_dt_acct payment_type  \
# 0                1      iPhone     2009-08-29         PMOF
# 1                2        iPad     2011-05-28         PMOF
# 2                2        iPad     2009-11-15         PMOF
# 3                2        iPad     2009-03-01         PMOF
# 4                2        iPad     2010-10-01         PMOF
# ...            ...         ...            ...          ...
# 3607504          1      iPhone     2011-06-18         PMOF
# 3607505          1      iPhone     2010-01-25         PMOF
# 3607506          2        iPad     2012-02-08         PMOF
# 3607507          2        iPad     2007-08-29         PMOF
# 3607508          1      iPhone     2009-01-23         PMOF
#
#         parent_app_content_id          type                  app_name  \
# 0            61cea77b9bc843d1  subscription           events Bildad's
# 1            1f0ebd67df5846cd    consumable        swell questionably
# 2            1383e4f2f49f0f44    consumable  supperless--my Shipmates
# 3            8590a25d4e5c249c    consumable          unwritten hungry
# 4            478e10f9248b7842    consumable           Turning thanked
# ...                       ...           ...                       ...
# 3607504      26e319612f771cb6    consumable            October genial
# 3607505      e59d81210fdc5594    consumable          flogging biscuit
# 3607506      8590a25d4e5c249c    consumable          unwritten hungry
# 3607507      a79e0d352f7fa8bc    consumable          remote remaining
# 3607508      606831f2120952a9    consumable           AS-IS vagueness
#
#         category_id  category_name
# 0               M-7      Utilities
# 1               M-7      Utilities
# 2               Z-1          Games
# 3               Z-1          Games
# 4               Q-1  Entertainment
# ...             ...            ...
# 3607504         Z-1          Games
# 3607505         Z-1          Games
# 3607506         Z-1          Games
# 3607507         Z-1          Games
# 3607508         Z-1          Games
#
# [2437496 rows x 13 columns]

# %%
df_wide[df_wide['payment_type'] == 'Free only']
# Out:
#         create_dt_transaction        content_id           acct_id  price  \
# 1752513            2016-08-19  1f6c4142d53f86d8  9744bbc81e980e62    0.0
# 1752514            2016-06-01  e7789212c7ae3a27  9ea14e08fccf1744    0.0
# 1752515            2016-08-31  973b3c5b875124d7  2ce32572b8c05773    0.0
# 1752516            2016-09-05  18573ca62bdc4b57  677d3ab6eca9e1b3    0.0
# 1752517            2016-09-14  a2f5435e63872446  222c99662138a386    0.0
# ...                       ...               ...               ...    ...
# 2920889            2016-07-08  b3aee7c1086c0237  1eaf9b5cbe9ef7d2    0.0
# 2920890            2016-09-18  ed4dd6eaa31b07ac  edd5f596bdc072f2    0.0
# 2920891            2016-08-13  641c23bc07b4683d  dc3fc7891fe8dfce    0.0
# 2920892            2016-08-14  0c204b2454654e0a  c9192fc140ba8b64    0.0
# 2920893            2016-06-05  5e076c64fb082ea5  650fc5b858704f08    0.0
#
#          device_id device_name create_dt_acct payment_type  \
# 1752513          2        iPad     2013-06-30    Free only
# 1752514          1      iPhone     2014-11-25    Free only
# 1752515          1      iPhone     2016-02-14    Free only
# 1752516          2        iPad     2013-03-15    Free only
# 1752517          1      iPhone     2015-08-16    Free only
# ...            ...         ...            ...          ...
# 2920889          1      iPhone     2017-06-07    Free only
# 2920890          2        iPad     2017-03-17    Free only
# 2920891          2        iPad     2013-04-11    Free only
# 2920892          1      iPhone     2013-06-29    Free only
# 2920893          1      iPhone     2016-05-11    Free only
#
#         parent_app_content_id type app_name category_id category_name
# 1752513                   NaN  NaN      NaN         NaN           NaN
# 1752514                   NaN  NaN      NaN         NaN           NaN
# 1752515                   NaN  NaN      NaN         NaN           NaN
# 1752516                   NaN  NaN      NaN         NaN           NaN
# 1752517                   NaN  NaN      NaN         NaN           NaN
# ...                       ...  ...      ...         ...           ...
# 2920889                   NaN  NaN      NaN         NaN           NaN
# 2920890                   NaN  NaN      NaN         NaN           NaN
# 2920891                   NaN  NaN      NaN         NaN           NaN
# 2920892                   NaN  NaN      NaN         NaN           NaN
# 2920893                   NaN  NaN      NaN         NaN           NaN
#
# [1167271 rows x 13 columns]

# %%
df_wide[df_wide['payment_type'] == 'PMOF']['content_id'].unique().shape
# Out:
# (2689,)

# %%
df_wide[df_wide['payment_type'] == 'Free only']['content_id'].unique().shape
# Out:
# (224,)

# %%
df_wide[df_wide['payment_type'] == 'Free only']['category_name'].unique()
# Out:
# array([nan], dtype=object)

# %%
# free only content is not purchaseable

np.count_nonzero(np.isin(df_wide[df_wide['payment_type'] == 'PMOF']['content_id'].unique(),
df_wide[df_wide['payment_type'] == 'Free only']['content_id'].unique()))
# Out:
# 0

# %%
df_wide[(df_wide['payment_type'] == 'PMOF') & (df_wide['content_id'] == '1f6c4142d53f86d8')]
# Out:
# Empty DataFrame
# Columns: [create_dt_transaction, content_id, acct_id, price, device_id, device_name, create_dt_acct, payment_type, parent_app_content_id, type, app_name, category_id, category_name]
# Index: []

# %%
df_wide[df_wide['payment_type'].isnull()]
# Out:
#         create_dt_transaction        content_id           acct_id  price  \
# 1208               2016-07-02  a792117e156607c2  9488918622974672   2.99
# 2511               2016-07-14  cc6e70d345f85276  4349884688257852   3.99
# 2714               2016-06-01  03230f058d847c64  1620038656801380  12.99
# 3335               2016-06-08  02f812e3c914b878  1919129874916410   8.99
# 4216               2016-08-19  fa35fc98975a6c4e  1984215081970279  14.99
# ...                       ...               ...               ...    ...
# 3597503            2016-06-04  ec1daca234e3478b  4722279452604405  11.99
# 3601223            2016-08-30  cbfbd041ab4c6183  8287202711385408   4.99
# 3602626            2016-08-29  3e195280a0a7d577  4907866555694471  10.99
# 3605113            2016-06-20  feacaa282731ff97  8287202711385408  25.99
# 3606374            2016-06-21  dd2d39bf12eafdd1  6528943452453481  20.99
#
#          device_id device_name create_dt_acct payment_type  \
# 1208             1      iPhone            NaT          NaN
# 2511             1      iPhone            NaT          NaN
# 2714             1      iPhone            NaT          NaN
# 3335             1      iPhone            NaT          NaN
# 4216             1      iPhone            NaT          NaN
# ...            ...         ...            ...          ...
# 3597503          1      iPhone            NaT          NaN
# 3601223          1      iPhone            NaT          NaN
# 3602626          2        iPad            NaT          NaN
# 3605113          2        iPad            NaT          NaN
# 3606374          1      iPhone            NaT          NaN
#
#         parent_app_content_id        type                 app_name  \
# 1208         21ae2d63b7280de1  consumable        Sleet's perceived
# 2511         d9ac236641bd3859  consumable        words: hospitable
# 2714         9f209b69e6c6de9e  consumable  STARTTHE butter--twenty
# 3335         65b4d55761b9b52c  consumable       clayey courteously
# 4216         ac9b3b9697787ad8  consumable           animals levels
# ...                       ...         ...                      ...
# 3597503      dbfe06aef68805a7  consumable              Dan disease
# 3601223      606831f2120952a9  consumable          AS-IS vagueness
# 3602626      c468c1ba007914f3  consumable        authority quality
# 3605113      8590a25d4e5c249c  consumable         unwritten hungry
# 3606374      a97a0c4386d37a1f  consumable             ceases half;
#
#         category_id      category_name
# 1208            Q-5  Social Networking
# 2511            Z-1              Games
# 2714            Z-1              Games
# 3335            Z-1              Games
# 4216            Z-1              Games
# ...             ...                ...
# 3597503         Z-1              Games
# 3601223         Z-1              Games
# 3602626         Z-1              Games
# 3605113         Z-1              Games
# 3606374         Z-1              Games
#
# [2742 rows x 13 columns]

# %%
df_wide['payment_type'].unique()
# Out:
# array(['PMOF', nan, 'Free only'], dtype=object)

# %%
df_wide.isna().sum()
# Out:
# create_dt_transaction          0
# content_id                     0
# acct_id                        0
# price                          0
# device_id                      0
# device_name                    0
# create_dt_acct              2742
# payment_type                2742
# parent_app_content_id    1594364
# type                     1594364
# app_name                 1594364
# category_id              1594364
# category_name            1594364
# dtype: int64

# %% [markdown]
# ## Investigate Subscription Accounts
# all price>0 transactions are from subscription accounts?

# %%
acct_sub = df_wide[df_wide['type'] == 'subscription']['acct_id'].unique()

# %%
df_wide[df_wide['acct_id'].isin(acct_sub)]['price'].count()
# Out:
# 2439128

# %%
df_wide[df_wide['acct_id'].isin(acct_sub)]['price'].sum()
# Out:
# 19049491.849999975

# %%
df_wide[df_wide['acct_id'].isin(acct_sub)]['price'].sum()/df_wide[df_wide['acct_id'].isin(acct_sub)]['price'].count()
# Out:
# 7.809959891403803

# %%
df_wide[~df_wide['acct_id'].isin(acct_sub)]['price'].count()
# Out:
# 1168381

# %%
df_wide[~df_wide['acct_id'].isin(acct_sub)]['price'].sum()
# Out:
# 0.0

# %%
df_wide[(df_wide['acct_id'].isin(acct_sub)) &
       (df_wide['payment_type'] == 'Free only')]['content_id'].count()
# Out:
# 0

# %%
df_wide[(df_wide['acct_id'].isin(acct_sub)) &
       ~(df_wide['payment_type'] == 'Free only')]
# Out:
#         create_dt_transaction        content_id           acct_id  price  \
# 0                  2016-08-28  b6cf4f33e7455df4  220574a7a6a71afa  11.99
# 1                  2016-09-16  71ac3e9c38ddbbba  8551f69a5015ea6a   1.99
# 2                  2016-08-15  776b851b916c33d1  7dedf309494a1966   0.99
# 3                  2016-06-17  7a47ca132a8dc695  7174a81c796dcf7e   1.99
# 4                  2016-06-13  30581219bc952dbb  35aaf59d64a677e7  11.99
# ...                       ...               ...               ...    ...
# 3607504            2016-07-11  330640111f15f83e  42f1c3996d40fa49  27.99
# 3607505            2016-08-05  2364a51706a7f5a3  63f4e3bbaf70abbe   2.99
# 3607506            2016-06-28  26aebfbbaec60a96  402001eac02d9f8a   6.99
# 3607507            2016-06-09  77ee563bf7d7c534  514434e3ad0b8e64   2.99
# 3607508            2016-07-17  d0ae61e1a666bd74  b884477673ef801d  11.99
#
#          device_id device_name create_dt_acct payment_type  \
# 0                1      iPhone     2009-08-29         PMOF
# 1                2        iPad     2011-05-28         PMOF
# 2                2        iPad     2009-11-15         PMOF
# 3                2        iPad     2009-03-01         PMOF
# 4                2        iPad     2010-10-01         PMOF
# ...            ...         ...            ...          ...
# 3607504          1      iPhone     2011-06-18         PMOF
# 3607505          1      iPhone     2010-01-25         PMOF
# 3607506          2        iPad     2012-02-08         PMOF
# 3607507          2        iPad     2007-08-29         PMOF
# 3607508          1      iPhone     2009-01-23         PMOF
#
#         parent_app_content_id          type                  app_name  \
# 0            61cea77b9bc843d1  subscription           events Bildad's
# 1            1f0ebd67df5846cd    consumable        swell questionably
# 2            1383e4f2f49f0f44    consumable  supperless--my Shipmates
# 3            8590a25d4e5c249c    consumable          unwritten hungry
# 4            478e10f9248b7842    consumable           Turning thanked
# ...                       ...           ...                       ...
# 3607504      26e319612f771cb6    consumable            October genial
# 3607505      e59d81210fdc5594    consumable          flogging biscuit
# 3607506      8590a25d4e5c249c    consumable          unwritten hungry
# 3607507      a79e0d352f7fa8bc    consumable          remote remaining
# 3607508      606831f2120952a9    consumable           AS-IS vagueness
#
#         category_id  category_name
# 0               M-7      Utilities
# 1               M-7      Utilities
# 2               Z-1          Games
# 3               Z-1          Games
# 4               Q-1  Entertainment
# ...             ...            ...
# 3607504         Z-1          Games
# 3607505         Z-1          Games
# 3607506         Z-1          Games
# 3607507         Z-1          Games
# 3607508         Z-1          Games
#
# [2439128 rows x 13 columns]
